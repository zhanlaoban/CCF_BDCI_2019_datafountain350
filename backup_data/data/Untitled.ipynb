# %%
import pandas as pd
import os
import random




train_df=pd.read_csv("Train_DataSet.csv")
train_label_df=pd.read_csv("Train_DataSet_Label.csv")
test_df=pd.read_csv("Test_DataSet.csv")
train_df=train_df.merge(train_label_df,on='id',how='left')
train_df['label']=train_df['label'].fillna(-1)
train_df=train_df[train_df['label']!=-1]
train_df['label']=train_df['label'].astype(int)
test_df['label']=0

test_df['content']=test_df['content'].fillna('无')
train_df['content']=train_df['content'].fillna('无')
test_df['title']=test_df['title'].fillna('无')
train_df['title']=train_df['title'].fillna('无')

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7340 entries, 0 to 7344
# Data columns (total 4 columns):
# id         7340 non-null object
# title      7340 non-null object
# content    7340 non-null object
# label      7340 non-null int64
# dtypes: int64(1), object(3)
# memory usage: 286.7+ KB

# %%
len((train_df['label'] == 0) == True)
# Out:
# 7340

# %%
train_df['label'].value_counts()
# Out:
# 1    3646
# 2    2931
# 0     763
# Name: label, dtype: int64

# %%
test_df = pd.read_csv('10_06_2_WeightedVotingEnsemble.csv')

# %%
test_df['label'].value_counts()
# Out:
# 1    3594
# 2    2958
# 0     804
# Name: label, dtype: int64

# %%
df = pd.read_csv('data_0/train.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f729d181bb31> in <module>()
# ----> 1 df = pd.read_csv('data_0/train.csv')
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd
df = pd.read_csv('data_0/train.csv')

# %%
df[['id','content','title','label']].values
# Out:
# array([['fe652ea833d548c0a503c9c197baa7fd',
#         '玩绝地求生最刺激的地方除了吃鸡和杀人外，就非追空投莫属了，空投箱有地图上不刷新的好武器，每次听到飞机的轰鸣声，连孤存都按捺不住激动，不顾有一切去追梦，看到awp或者m24的那一瞬间简直不要太爽，如果再加上一个狙击消音器，订书机般美妙的枪声了解一下？当然啦，空投补给箱也同样分三六九等，并不是每个补给箱都会有大狙这样的好装备，像mk14狙击枪就往往无人问津，大菠萝m249班机枪同样让人难以抉择，相信各位小伙伴在面对满配m4和大菠萝二选一时头疼不已。经常使用m4无疑更加顺手，而冒着生命危险追的补给箱却给了一把优缺分明的机枪，多少有点食之无味弃之可惜，接下来小编就给大家提供一下这两把枪的参数，希望看完后对你今后的选择有帮助。后座力和射速后座力的大小是决定使用它的决定性因素，m4和m249在同样站立开火的情况下，前面十发子弹基本都是在同一水平线上，之后大菠萝的子弹会因为后座力巨大而发生歪曲，但是相对于m4，垂直后座力明显小很多它更合适趴着或者蹲下输出，因此，m249更合适伏地魔和习惯蹲下来打的玩家。在射速方面，同样打40发子弹的情况下，大菠萝的射速稍微快一些。子弹和装高倍镜后的使用效果这两把枪都使用5.56的子弹，m4配合扩充弹夹最多只能装下40发，而号称载具毁灭者的大菠萝可以装备高达100发，在换子弹需要的时间上，m4只需两秒出头，大菠萝因为子弹多的原因，换弹夹需要八秒多。有换“子弹癌”的小伙伴需要注意啦，这两把枪同样装上高倍镜后，大菠萝镜头晃动频率较大，m4的稳定性明显更好，如果是远距离开枪，m4是最好的选择。综上所述，m249需要更多的技巧才能灵活运用，非常合适高手使用，而m4则因为常见的原因和易上手的特点，更合适新手玩家使用。以上测评数据均由知名游戏博主“小墨不是小莫”提供，而他本人也将从幕后走到台前，以前小墨主要为网友制作精彩的绝地求生视频，而之后自己也会亲自直播，之后的视频素材将会出自小墨的直播间哦。小墨将于5月4日晚在企鹅电竞首播，届时除了直播吃鸡送红包外，还会有很多实用教学！感兴趣的小伙伴千万不要错过。本文为一点号作者原创，未经授权不得转载',
#         '绝地求生：多数玩家面对这两把枪时常常犹豫不决，你会如何选择？', 1],
# ...

# %%
for val in df[['id','content','title','label']].values:
    #text_a对应content, text_b对应title
    #examples.append(InputExample(guid=val[0], text_a=val[1], text_b=val[2], label=val[3]))
    print(val)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# ['a744a0164f384d64ab438f81f9b2f092'
# ...
